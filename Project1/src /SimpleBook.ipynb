# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

fights = pd.read_csv("../data/all_fights.csv")
print(fights.shape)
print(fights.describe)
# Out:
# (7265, 57)
# <bound method NDFrame.describe of                    red_fighter       blue_fighter  red_odds  blue_odds  \
# 0            Alexandre Pantoja        Kai Asakura      -250        215
# 1            Shavkat Rakhmonov  Ian Machado Garry      -210        295
# 2                   Ciryl Gane   Alexander Volkov      -380        300
# 3               Bryce Mitchell        Kron Gracie      -950        625
# 4                Nate Landwehr         Dooho Choi      -130        110
# ...                        ...                ...       ...        ...
# 7260        Rayanne dos Santos     Alice Ardelean      -230        195
# 7261                  Shi Ming       Bruna Brasil       320       -410
# 7262  Nyamjargal Tumendemberel  Terrance Saeteurn      -110       -110
# 7263                 Xiao Long        SuYoung You       125       -145
# 7264              Elijah Smith        SuYoung You      -260        220
#
#      red_winner  red_return  blue_return  odds_diff  age_diff  reach_diff  \
# 0             t      1.4000         0.00       -465         3       -5.08
# 1             t      1.4762         0.00       -505         3        7.62
# 2             t      1.2632         0.00       -680        -2        2.54
# 3             t      1.1053         0.00      -1575        -6        0.00
# 4             f      0.0000         2.10       -240         3        5.08
# ...         ...         ...          ...        ...       ...         ...
# 7260          f      0.0000         2.95       -425        -4        0.00
# 7261          f      0.0000         1.24        730        -1      -12.70
# 7262          t      1.9100         0.00          0        -3       10.16
# 7263          f      0.0000         1.69        270        -2       12.70
# 7264          t      1.3800         0.00       -480        -7       15.24
#
#       ...  red_wins_by_ko  red_wins_by_submission  red_wins  red_stance  \
# 0     ...               2                       4        12    Orthodox
# 1     ...               1                       5         6    Orthodox
# 2     ...               4                       2         9    Orthodox
# 3     ...               0                       1         7    Southpaw
# 4     ...               1                       2         5    Orthodox
# ...   ...             ...                     ...       ...         ...
# 7260  ...               0                       0         0    Orthodox
# 7261  ...               1                       0         3    Orthodox
# 7262  ...               0                       1         2    Orthodox
# 7263  ...               1                       0         3    Orthodox
# 7264  ...               1                       0         3    Orthodox
#
#       red_height_cms  red_reach_cms  red_age  blue_age  b_match_wc_rank  \
# 0             165.10         170.18       34        31               20
# 1             185.42         195.58       30        27                7
# 2             193.04         205.74       34        36                3
# 3             177.80         177.80       30        36               20
# 4             175.26         182.88       36        33               20
# ...              ...            ...      ...       ...              ...
# 7260          157.48         157.48       29        33               20
# 7261          157.48         152.40       30        31               20
# 7262          170.18         180.34       27        30               20
# 7263          172.72         177.80       27        29               20
# 7264          175.26         180.34       23        30               20
#
#       r_match_wc_rank
# 0                   0
# 1                   3
# 2                   2
# 3                  13
# 4                  20
# ...               ...
# 7260               20
# 7261               20
# 7262               20
# 7263               20
# 7264               20
#
# [7265 rows x 57 columns]>

# %%
print("===Info===")
print(fights.info())
print('===Red Winner===')
print(fights['red_winner'].value_counts())

# %% [markdown]
# preprocess
